# %%
print("Hello world")

# %%
print("Hello back Astrid")

# %% [markdown]
# # This is header 1
# And it's very informative
# ## This is a smaller header
# Can you even read it?

# %%
print("test")

# %%
a = 1 
b = 2
c = a + b
print(c)
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
h = 3.12
g = 3
b = h + g

type(g), type(h), type(b)
# Out:
# (int, float, float)

# %%
c = "Hello, this is a string"

type(c)

len(c)
# Out:
# 23

# %%
# Lists
shopping = ["Apples", "Dragon fruit", "Watermelon"]
scores = [90, 21, 44, 53, 11]
mixed = ["Dog", 23, "Cavalier"]
combined = [shopping, scores, mixed]
print(combined)
type(combined)
# Out:
# [['Apples', 'Dragon fruit', 'Watermelon'], [90, 21, 44, 53, 11], ['Dog', 23, 'Cavalier']]
# list

# %%
print(shopping[0])
# Out:
# Apples

# %%
print(shopping[0:3])
# Out:
# ['Apples', 'Dragon fruit', 'Watermelon']

# %%
#Tuples
Shopping_tuple = ("Apples", "Dragon fruit", "Watermelon")
shopping[0] = "Pears"
print(shopping)
print(shopping)
#This gives us an error
# Out:
# ['Pears', 'Dragon fruit', 'Watermelon']
# ['Pears', 'Dragon fruit', 'Watermelon']

# %%
Names = ["Anna", "Peter", "Anna", "Oscar", "Peter"]
Unique_names_list = set(Names)
print(Unique_names_list)
#We can check if some name is in the list
Check_Peter = "Peter" in Names
print(Check_Peter)
Check_Bob = "Bob" in Names
print(Check_Bob)
#We can make the set into a list, so we can index it
Names = list(Names)
Names[0]
# Out:
# {'Anna', 'Oscar', 'Peter'}
# True
# False
# 'Anna'

# %%
#Dictionaries
Dictionary = {
    "Name": "Christian"
}
Dictionary["Name"]
# Out:
# 'Christian'

# %%
Dictionary_2 = {
    "Name": "Christian",
    "Age": 24,
    "Interrest": "Climbing",
    "Pet": "Dog"
}
print(len(Dictionary_2))
print(Dictionary_2)
print(Dictionary_2["Age"])
#We can update the dictionary
Dictionary_2.update({"Age": 25})
Dictionary_2["Age"]
# Out:
# 4
# {'Name': 'Christian', 'Age': 24, 'Interrest': 'Climbing', 'Pet': 'Dog'}
# 24
# 25

# %%
#Dictionaties again
#We can make an empty one
Dictionary_3 = {
    "Christian":{
        "Name": "Christian",
        "Age": 24,
        "Species": "Human"
    },
        "Other_guy":{
        "Name": "Other_guy",
        "Age": 382,
        "Species": "Other"
    }
}
Dictionary_3["Christian"]
# Out:
# {'Name': 'Christian', 'Age': 24, 'Species': 'Human'}
