# %% [markdown]
# # CDS Lecture 02 - Group Exercise
#
# Below you can find a dataset of songs contained in a dictionary. In this exercise you will be prompted to access values in the dictionary and use the knowledge you gained in lecture today to create new variables.

# %%
# Regular variables - Strings. 

# Make a character variable with your name.

Name = "Christian"

# Make a character variable with your best friend's name.

Best_Friend = "My_Best_Friend"

# Get the length of your name. 

print(len(Name))

# Get the length of your friend's name.

print(len(Best_Friend))

# Make a character variable with the expression "My name is X" (where you print your name in place of). 

Character_Variable = f"My name is {Name}"

# Get the length of the character variable from the previous step. Does this include spaces?

len(Character_Variable)

#Yes, this does include spaces
# Out:
# 9
# 14
# 20

# %%
# Regular variables - Integers.

# Make an integer variable with your age (rounded down).

Age = 24
print(Age)

# Make a floating point variable with your age to the precise month.

Precise_Age = 24.2
print(Precise_Age)

# Add your integer age and your floating point age and store the value in a variable. 

Combined_Age = Age + Precise_Age
print(Combined_Age)

# Get the type of the variable from the previous step. Is it floating point or integer? Why?
type(Combined_Age)
#It is a floating point, due to the decimal from Precise_Age
# Out:
# 24
# 24.2
# 48.2
# float

# %%
# Lists.

# make your own shopping list with 10 items and store in a list variable.

Shopping_list = ["Apples", "Pears", "Bananas", "Dragon fruit", "Watermelon", "Litchi", "Mango", "Pineapple", "Grapes", "Orange"]

# make a list of items that you would get if you had extra spending money and store in a list variable. 

Extra_Shopping_list = ["Lobster", "Beef", "Champagne", "Caviar"]

# now combine these lists and store in a new variable. 

Total_Shopping_list = Shopping_list + Extra_Shopping_list

# now print the first item in your (original) shopping list.

print(Shopping_list[0])

# now print the fifth item.

print(Shopping_list[4])

# Now print items 3-8.

print(Shopping_list[2:8])

# Now get the length of the list.

len(Shopping_list)

# Now add an item to the end of the list.

Shopping_list.append("Lemon")

print(Shopping_list)

# Now insert and item between the 3rd and 4th items.

Shopping_list.insert(3, "Carrot")
print(Shopping_list)

# Now get the new list length.
len(Shopping_list)
# Out:
# Apples
# Watermelon
# ['Bananas', 'Dragon fruit', 'Watermelon', 'Litchi', 'Mango', 'Pineapple']
# ['Apples', 'Pears', 'Bananas', 'Dragon fruit', 'Watermelon', 'Litchi', 'Mango', 'Pineapple', 'Grapes', 'Orange', 'Lemon']
# ['Apples', 'Pears', 'Bananas', 'Carrot', 'Dragon fruit', 'Watermelon', 'Litchi', 'Mango', 'Pineapple', 'Grapes', 'Orange', 'Lemon']
# 12

# %%
# Tuples.

# now convert your shopping list to a tuple. 

Shopping_list_tuple = tuple(Shopping_list)
print(Shopping_list_tuple)

# try adding an item to your tuple. What happens?

Shopping_list_tuple.append("Strawberry")
#So we get an error, which is expected
# Out:
# ('Apples', 'Pears', 'Bananas', 'Carrot', 'Dragon fruit', 'Watermelon', 'Litchi', 'Mango', 'Pineapple', 'Grapes', 'Orange', 'Lemon')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 10
#       6 print(Shopping_list_tuple)
#       7
#       8 # try adding an item to your tuple. What happens?
#       9
# ---> 10 Shopping_list_tuple.append("Strawberry")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Sets.

# Make a set of your best friends' names. 

Best_friends_names = ["Melanie", "Maiken", "Sarah", "Adi", "Melanie"]
Best_friends_names = set(Best_friends_names)
# Try adding a name.

#Best_friends_names.append("Cilja")
#We cannot do that

# Try indexing the set. 

#Best_friends_names[1]
#We cannotdo that either

# Try adding a duplicate. 

#See above (cannot add here)

# Print the set again. 

print(Best_friends_names)

# Check whether the name "Anna" is in your set.

Check_Anna = "Anna" in Best_friends_names
print(Check_Anna)
# Out:
# {'Adi', 'Melanie', 'Sarah', 'Maiken'}
# False

# %%
# Dictionaries.

# Make a simple dictionary containing information about your favorite song and store in a variable:
# - The dictionary has one entry (your favorite song)
# - The dictionary has the following keys:
    # - Title
    # - Year
    # - Genre
    # - Duration
    # - Composer
    # - Artist 
# (Look this information up if you do not know it off the top of your head)

# Now make a multi-entry dictionary (5 - 10 entries) that contains the above information for each entry. 

# Get the length of the dictionary to make sure that the number of entries corresponds to what you entered. 

# Look up the title for the one of the songs in the dictionary and store in a variable. 

# Look up the title for another song in the variable and store in a variable.

# Create a new list that contains these two new variables as items.

# %%
# This dictionary contains information about one song. 
songs = {
    "Imagine": {
        "artist": "John Lennon",
        "year": 1971,
        "genre": "Rock",
        "rating": 9.5
    }
}

# add "Respect" to the songs dictionary using the information below:
#    Artist: Aretha Franklin
#    Year: 1967
#    Genre: Soul
#    Rating: 9.2

# add "Bohemian Rhapsody":
#    Artist: Queen
#    Year: 1975
#    Genre: Rock
#    Rating: 9.7

# 3. Print the complete songs dictionary.

# 4. Print the artist of "Respect".

# 5. Print the rating of "Bohemian Rhapsody".

# %% [markdown]
# ## 6. Reflection
# Variables help us organize, access, and analyze cultural data efficiently!
#
# Add a markdown chunk below where you summarize key features of the different types of variables you have learned about today:
#
# - Regular string
# - Regular integer
# - Regular floating point
# - Container variables:
#     - List
#     - Set
#     - Tuple
#     - Dictionary

# %% [markdown]
# # Final task.
#
# Export this notebook to an HTML file, view in your browswer, and upload the file to your CulturalDataScience Git repo (on UCloud).
#
# Then push your changes back to Github.
